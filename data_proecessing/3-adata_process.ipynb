# %%
import anndata as ad
import csv
import numpy as np
import pandas as pd
import scanpy as sc
from scipy.sparse import csr_matrix

# %%
OLINK_total = pd.read_csv('../../data/2-updated_OLINK_data_nanToZero.csv')
OLINK_total.shape
# Out:
# (41449, 2920)

# %%
OLINK_total.head()
# Out:
#         Id  EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2  \
# 0  1000221  0.757567  1.059738  0.815933  0.763303  0.911962  0.988546
# 1  1000326  1.062782  2.293678  0.000000  0.000000  0.940864  0.816711
# 2  1000662  1.042251  1.417310  0.940098  0.967622  1.076896  1.092434
# 3  1000823  1.391736  1.279477  0.871398  1.103463  1.140979  1.412810
# 4  1000945  0.910838  0.286904  0.736551  0.884847  0.933054  0.749714
#
#       ENPP5     ENPP7    ENTPD5  ...    CHCHD6       CHM      CHP1     CHMP6  \
# 0  0.661753  0.497269  1.032355  ...  0.856418  0.818377  0.875872  0.808958
# 1  0.941631  1.968941  0.968208  ...  1.015154  1.980759  0.743593  1.033172
# 2  1.242879  0.807585  1.054544  ...  1.123415  1.348269  0.834863  1.147824
# 3  0.917597  1.007419  1.104586  ...  0.987505  1.353375  0.934770  1.208649
# 4  0.000000  0.000000  0.890822  ...  0.812096  0.526413  0.859511  0.316076
#
#      CHMP1A      CHGB      CHGA     CHRM1      KLK1     WFDC2
# 0  1.000000  0.829799  2.176731  1.150268  0.000000  0.000000
# 1  2.281750  0.000000  2.056565  0.985895  0.734873  0.000000
# 2  1.316108  1.107852  0.452451  0.964498  0.969676  1.186373
# 3  1.212596  0.889118  1.657512  1.032764  0.871443  1.258823
# 4  0.456966  0.722186  1.486522  0.849878  3.465817  1.057866
#
# [5 rows x 2920 columns]

# %% [markdown]
# ### Get the sub dataset

# %%
# small_df = OLINK_total.sample(frac=0.2, random_state=66)
small_df = OLINK_total.sample(frac=0.3, random_state=66)
small_df.shape
# Out:
# (12435, 2920)

# %%
small_df
# Out:
#             Id  EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2  \
# 13855  2677744  1.000000  0.918538  0.838626  1.128345  1.023336  0.959534
# 36655  5442589  0.892758  1.216096  0.806386  0.930984  0.815113  1.060883
# 41208  5995054  1.359714  1.514193  1.131876  1.173802  0.929273  0.997802
# 7917   1969066  0.843706  1.168799  0.904953  0.813905  1.011697  0.888383
# 37474  5540794  1.041274  1.097060  0.976544  1.747628  1.004245  1.023405
# ...        ...       ...       ...       ...       ...       ...       ...
# 33131  5002917  0.878127  0.575196  0.941487  1.142237  1.089860  0.973155
# 13104  2594709  0.912384  1.269972  1.067561  0.930461  1.225803  1.023405
# 10709  2304029  0.924675  1.317994  1.047662  1.141362  0.938806  0.859758
# 5489   1671052  1.757755  2.406449  0.950528  0.999900  1.063201  1.115266
# 16735  3015937  1.202419  1.923696  1.120118  1.415747  0.963913  0.922122
#
#           ENPP5     ENPP7    ENTPD5  ...    CHCHD6       CHM      CHP1  \
# 13855  1.140160  0.000000  0.959825  ...  0.851392  0.773959  1.000075
# 36655  1.005912  0.563765  1.122820  ...  1.105924  1.107692  0.000000
# 41208  1.007821  0.883290  0.945952  ...  1.020440  0.931365  1.029011
# 7917   0.781125  1.277478  0.830456  ...  0.962914  0.859219  0.724947
# 37474  1.343416  1.065035  0.851704  ...  1.020440  0.000000  0.951421
# ...         ...       ...       ...  ...       ...       ...       ...
# 33131  1.473499  1.808478  0.970753  ...  1.086920  0.826044  1.325103
# 13104  1.385987  1.071540  1.183964  ...  0.900767  0.851838  0.960725
# 10709  0.845523  0.590299  0.942974  ...  1.051487  1.335131  0.972934
# 5489   1.255159  0.705404  0.967866  ...  1.046682  1.643609  1.481157
# 16735  1.037833  0.633972  0.987703  ...  1.197929  1.514063  0.937706
#
#           CHMP6    CHMP1A      CHGB      CHGA     CHRM1      KLK1     WFDC2
# 13855  0.982162  1.071514  0.853623  2.307786  0.630636  0.516765  0.956622
# 36655  0.950432  0.878537  0.990531  0.610571  1.385925  0.543388  0.764618
# 41208  1.335312  1.244005  1.447208  1.343598  1.104265  0.842998  1.815272
# 7917   0.923540  1.006012  0.840478  1.047611  0.999650  0.788088  0.901370
# 37474  0.994959  0.771263  1.470941  2.527919  0.000000  1.127315  1.052732
# ...         ...       ...       ...       ...       ...       ...       ...
# 33131  0.807971  0.480938  1.040349  1.337788  1.027049  0.956986  1.102822
# 13104  0.953669  0.843286  0.844105  0.578261  1.001951  0.782882  0.000000
# 10709  1.147331  1.055425  0.897057  0.647238  1.575910  2.420177  0.988546
# 5489   1.721467  1.453993  1.241609  1.682197  0.866556  0.562569  1.440820
# 16735  1.135032  1.693438  0.933078  0.998351  1.013159  0.917220  0.767378
#
# [12435 rows x 2920 columns]

# %%
OLINK = small_df
# OLINK.to_csv("../data/3-OLINK_data_sub.csv", index = False)

# %% [markdown]
# ### Process the sub dataset

# %%
# OLINK = pd.read_csv('../data/3-OLINK_data_sub.csv')

# %%
OLINK.head()
# Out:
#             Id  EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2  \
# 13855  2677744  1.000000  0.918538  0.838626  1.128345  1.023336  0.959534
# 36655  5442589  0.892758  1.216096  0.806386  0.930984  0.815113  1.060883
# 41208  5995054  1.359714  1.514193  1.131876  1.173802  0.929273  0.997802
# 7917   1969066  0.843706  1.168799  0.904953  0.813905  1.011697  0.888383
# 37474  5540794  1.041274  1.097060  0.976544  1.747628  1.004245  1.023405
#
#           ENPP5     ENPP7    ENTPD5  ...    CHCHD6       CHM      CHP1  \
# 13855  1.140160  0.000000  0.959825  ...  0.851392  0.773959  1.000075
# 36655  1.005912  0.563765  1.122820  ...  1.105924  1.107692  0.000000
# 41208  1.007821  0.883290  0.945952  ...  1.020440  0.931365  1.029011
# 7917   0.781125  1.277478  0.830456  ...  0.962914  0.859219  0.724947
# 37474  1.343416  1.065035  0.851704  ...  1.020440  0.000000  0.951421
#
#           CHMP6    CHMP1A      CHGB      CHGA     CHRM1      KLK1     WFDC2
# 13855  0.982162  1.071514  0.853623  2.307786  0.630636  0.516765  0.956622
# 36655  0.950432  0.878537  0.990531  0.610571  1.385925  0.543388  0.764618
# 41208  1.335312  1.244005  1.447208  1.343598  1.104265  0.842998  1.815272
# 7917   0.923540  1.006012  0.840478  1.047611  0.999650  0.788088  0.901370
# 37474  0.994959  0.771263  1.470941  2.527919  0.000000  1.127315  1.052732
#
# [5 rows x 2920 columns]

# %%
OLINK=OLINK.set_index('Id')
# OLINK.columns=([a[2:] for a in OLINK.columns])
OLINK.index.names = ['Id']
OLINK.head()
# Out:
#          EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2     ENPP5  \
# Id
# 2677744  1.000000  0.918538  0.838626  1.128345  1.023336  0.959534  1.140160
# 5442589  0.892758  1.216096  0.806386  0.930984  0.815113  1.060883  1.005912
# 5995054  1.359714  1.514193  1.131876  1.173802  0.929273  0.997802  1.007821
# 1969066  0.843706  1.168799  0.904953  0.813905  1.011697  0.888383  0.781125
# 5540794  1.041274  1.097060  0.976544  1.747628  1.004245  1.023405  1.343416
#
#             ENPP7    ENTPD5     EGLN1  ...    CHCHD6       CHM      CHP1  \
# Id                                     ...
# 2677744  0.000000  0.959825  1.143194  ...  0.851392  0.773959  1.000075
# 5442589  0.563765  1.122820  0.812698  ...  1.105924  1.107692  0.000000
# 5995054  0.883290  0.945952  1.465609  ...  1.020440  0.931365  1.029011
# 1969066  1.277478  0.830456  0.784181  ...  0.962914  0.859219  0.724947
# 5540794  1.065035  0.851704  1.465067  ...  1.020440  0.000000  0.951421
#
#             CHMP6    CHMP1A      CHGB      CHGA     CHRM1      KLK1     WFDC2
# Id
# 2677744  0.982162  1.071514  0.853623  2.307786  0.630636  0.516765  0.956622
# 5442589  0.950432  0.878537  0.990531  0.610571  1.385925  0.543388  0.764618
# 5995054  1.335312  1.244005  1.447208  1.343598  1.104265  0.842998  1.815272
# 1969066  0.923540  1.006012  0.840478  1.047611  0.999650  0.788088  0.901370
# 5540794  0.994959  0.771263  1.470941  2.527919  0.000000  1.127315  1.052732
#
# [5 rows x 2919 columns]

# %%
range_per_column = OLINK.max() - OLINK.min()
print(range_per_column)

# 获取数据范围的最小值和最大值
min_range = range_per_column.min()
max_range = range_per_column.max()

print(min_range, max_range)
print(range_per_column.idxmin(), range_per_column.idxmax())
# Out:
# EIF4EBP1    2.251173
# EIF4G1      2.690604
# EIF5A       1.543532
# ENAH        1.885804
# ENG         1.295652
#               ...
# CHGB        1.728302
# CHGA        2.911971
# CHRM1       1.684814
# KLK1        4.140134
# WFDC2       1.854422
# Length: 2919, dtype: float64
# 1.125255683732487 7.972505423099521
# SERPINA1 SPINT3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

means = OLINK.mean()

plt.figure(figsize=(6, 3))
sns.scatterplot(x=means.index, y=means.values)
# Out:
# <Axes: xlabel='None'>

# %%
std_devs = OLINK.std()

plt.figure(figsize=(6, 3))
sns.scatterplot(x=std_devs.index, y=std_devs.values)
# Out:
# <Axes: xlabel='None'>

# %% [markdown]
# ### Split to train and test dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(OLINK, test_size=0.3, random_state=66)

# %%
X_train.shape
# Out:
# (8704, 2919)

# %%
X_test.shape
# Out:
# (3731, 2919)

# %%
X_train.head()
# Out:
#          EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2     ENPP5  \
# Id
# 5116579  1.712074  2.469646  0.785440  0.842069  0.976470  1.273487  1.065419
# 1355096  0.601038  0.784768  0.000000  0.000000  0.996504  1.228266  0.876486
# 1600706  0.987703  0.692846  0.728667  1.078791  1.115616  1.037628  0.993415
# 5086035  0.980484  0.636002  0.999850  1.731376  1.004256  0.907612  1.207231
# 2197383  1.093868  1.467300  0.874621  0.879678  1.071907  1.380622  1.066516
#
#             ENPP7    ENTPD5     EGLN1  ...    CHCHD6       CHM      CHP1  \
# Id                                     ...
# 5116579  1.018315  0.939619  1.637496  ...  1.095251  1.824805  0.992793
# 1355096  0.968575  0.751418  1.196604  ...  1.005109  0.873939  0.868432
# 1600706  1.622064  0.893635  1.476252  ...  1.033326  0.838846  0.911610
# 5086035  0.840302  0.936798  0.773834  ...  0.829165  1.173301  1.612761
# 2197383  0.574736  0.941056  0.896455  ...  1.034733  1.191790  1.003078
#
#             CHMP6    CHMP1A      CHGB      CHGA     CHRM1      KLK1     WFDC2
# Id
# 5116579  1.694267  1.040379  0.702624  0.913274  1.007268  2.757604  0.951687
# 1355096  0.603530  0.436987  1.416497  1.180887  1.098659  0.692884  1.253127
# 1600706  0.919245  0.998950  0.919575  0.755486  1.113652  2.591817  1.219973
# 5086035  0.859399  0.842113  0.872169  0.631203  1.060102  0.663189  0.890592
# 2197383  1.149307  1.211772  0.723999  1.030720  1.116101  1.088191  1.041068
#
# [5 rows x 2919 columns]

# %%
# X_train.to_csv("../data/3-OLINK_data_sub_train.csv")
# X_test.to_csv("../data/3-OLINK_data_sub_test.csv")

# %% [markdown]
# ### Normalization

# %% [markdown]
# 对数据进行 Min-Max 标准化处理

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_norm = scaler.fit_transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
X_train_norm
# Out:
# array([[0.76052534, 0.91787819, 0.50885876, ..., 0.60043866, 0.66606631,
#         0.51506589],
#        [0.26698901, 0.29167004, 0.        , ..., 0.65491698, 0.16735784,
#         0.678209  ],
#        [0.43875036, 0.25750568, 0.47207734, ..., 0.66385439, 0.62602259,
#         0.66026561],
#        ...,
#        [0.43712295, 0.38075239, 0.57576016, ..., 0.60924471, 0.63506152,
#         0.43919106],
#        [0.41319619, 0.38404996, 0.74093636, ..., 0.55354929, 0.21484488,
#         0.43503805],
#        [0.46483491, 0.25052216, 0.69812585, ..., 0.64779355, 0.24153808,
#         0.45156558]])

# %%
X_train_norm_df = pd.DataFrame(X_train_norm, columns=X_train.columns, index=X_train.index)
X_test_norm_df = pd.DataFrame(X_test_norm, columns=X_test.columns, index=X_test.index)

# %%
# X_train_norm_df.to_csv("../data/3-OLINK_data_sub_train_norm.csv")
# X_test_norm_df.to_csv("../data/3-OLINK_data_sub_test_norm.csv")

# %%
X_train_norm_df.head()
# Out:
#          EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2     ENPP5  \
# Id
# 5116579  0.760525  0.917878  0.508859  0.446824  0.753651  0.793501  0.635663
# 1355096  0.266989  0.291670  0.000000  0.000000  0.769114  0.765323  0.522939
# 1600706  0.438750  0.257506  0.472077  0.572435  0.861046  0.646539  0.592703
# 5086035  0.435544  0.236379  0.647767  0.918714  0.775097  0.565526  0.720272
# 2197383  0.485910  0.545342  0.566636  0.466781  0.827311  0.860256  0.636317
#
#             ENPP7    ENTPD5     EGLN1  ...    CHCHD6       CHM      CHP1  \
# Id                                     ...
# 5116579  0.399160  0.699962  0.771015  ...  0.719950  0.887078  0.399866
# 1355096  0.379663  0.559763  0.563421  ...  0.660697  0.424841  0.349778
# 1600706  0.635818  0.665707  0.695093  ...  0.679245  0.407781  0.367169
# 5086035  0.329382  0.697860  0.364360  ...  0.545042  0.570368  0.649570
# 2197383  0.225286  0.701032  0.422096  ...  0.680170  0.579355  0.404009
#
#             CHMP6    CHMP1A      CHGB      CHGA     CHRM1      KLK1     WFDC2
# Id
# 5116579  0.876770  0.448708  0.406737  0.313628  0.600439  0.666066  0.515066
# 1355096  0.312322  0.188469  0.819986  0.405528  0.654917  0.167358  0.678209
# 1600706  0.475702  0.430840  0.532326  0.259441  0.663854  0.626023  0.660266
# 5086035  0.444732  0.363198  0.504884  0.216761  0.631933  0.160185  0.482000
# 2197383  0.594757  0.522629  0.419111  0.353960  0.665314  0.262840  0.563440
#
# [5 rows x 2919 columns]

# %%
X_train_norm_df['Row_Sum'] = X_train_norm_df.sum(axis=1)
X_train_norm_df['Row_Sum'].mean()
# Out:
# 3067.502925643088

# %% [markdown]
# ### Construct the adata

# %%
def constructAdata(df):
    
    df.columns = df.columns.astype(str)
    df.index = df.index.astype(str)
    print(df.head())

    Odata = ad.AnnData(df)
    print(Odata)

    return Odata

# %%
Odata_train = constructAdata(X_train_norm_df)
Odata_test = constructAdata(X_test_norm_df)
# Out:
#          EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2     ENPP5  \
# Id
# 5116579  0.760525  0.917878  0.508859  0.446824  0.753651  0.793501  0.635663
# 1355096  0.266989  0.291670  0.000000  0.000000  0.769114  0.765323  0.522939
# 1600706  0.438750  0.257506  0.472077  0.572435  0.861046  0.646539  0.592703
# 5086035  0.435544  0.236379  0.647767  0.918714  0.775097  0.565526  0.720272
# 2197383  0.485910  0.545342  0.566636  0.466781  0.827311  0.860256  0.636317
#
#             ENPP7    ENTPD5     EGLN1  ...    CHCHD6       CHM      CHP1  \
# Id                                     ...
# 5116579  0.399160  0.699962  0.771015  ...  0.719950  0.887078  0.399866
# 1355096  0.379663  0.559763  0.563421  ...  0.660697  0.424841  0.349778
# 1600706  0.635818  0.665707  0.695093  ...  0.679245  0.407781  0.367169
# 5086035  0.329382  0.697860  0.364360  ...  0.545042  0.570368  0.649570
# 2197383  0.225286  0.701032  0.422096  ...  0.680170  0.579355  0.404009
#
#             CHMP6    CHMP1A      CHGB      CHGA     CHRM1      KLK1     WFDC2
# Id
# 5116579  0.876770  0.448708  0.406737  0.313628  0.600439  0.666066  0.515066
# 1355096  0.312322  0.188469  0.819986  0.405528  0.654917  0.167358  0.678209
# 1600706  0.475702  0.430840  0.532326  0.259441  0.663854  0.626023  0.660266
# 5086035  0.444732  0.363198  0.504884  0.216761  0.631933  0.160185  0.482000
# 2197383  0.594757  0.522629  0.419111  0.353960  0.665314  0.262840  0.563440
#
# [5 rows x 2919 columns]
# AnnData object with n_obs × n_vars = 8704 × 2919
#          EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2     ENPP5  \
# Id
# 2766252  0.354626  0.355038  0.661306  0.439131  0.831527  0.606274  0.735767
# 2254174  0.000000  0.356191  0.706649  0.498943  0.819847  0.614103  0.490196
# 4029539  0.373214  0.505016  0.681355  0.591761  0.787277  0.565177  0.000000
# 5423753  0.508880  0.308033  0.596615  0.388294  0.760944  0.623030  0.720137
# 2119269  0.650093  0.610542  0.612008  0.673229  0.825875  0.600577  0.713931
#
#             ENPP7    ENTPD5     EGLN1  ...    CHCHD6       CHM      CHP1  \
# Id                                     ...
# 2766252  0.597440  0.674971  0.384895  ...  0.531689  0.471773  0.321617
# 2254174  0.295777  0.000000  0.454157  ...  0.753103  0.417097  0.366414
# 4029539  0.000000  0.791305  0.577196  ...  0.613113  0.460831  0.416604
# 5423753  0.426166  0.773852  0.484138  ...  0.666785  0.409520  0.450378
# 2119269  0.000000  0.691442  0.368758  ...  0.640176  0.714063  0.369817
#
#             CHMP6    CHMP1A      CHGB      CHGA     CHRM1      KLK1     WFDC2
# Id
# 2766252  0.539730  0.431293  0.491928  0.315872  0.581142  0.333726  0.446029
# 2254174  0.484317  0.440394  0.502472  0.260339  0.662317  0.610050  0.563913
# 4029539  0.604385  0.529495  0.658723  0.300994  0.460298  0.150840  0.481751
# 5423753  0.477216  0.296426  0.529304  0.375883  0.569151  0.136981  0.534746
# 2119269  0.676487  0.552311  0.596017  0.680610  0.638814  0.253294  0.478247
#
# [5 rows x 2919 columns]
# AnnData object with n_obs × n_vars = 3731 × 2919

# %%
# OLINK_b = X_train_norm_df

# %%
# OLINK_b.columns = OLINK_b.columns.astype(str)
# OLINK_b.index = OLINK_b.index.astype(str)
# OLINK_b.head()

# %%
# Odata = ad.AnnData(OLINK_b)
# Odata

# %%
# print(Odata.var_names)

# %% [markdown]
# ### 基因匹配

# %%
def matchGenes(a):
    Odata = a.copy()
    with open('/data/mr423/project/data/keys_blood.txt', 'r') as file:
        genes_from_file = [line.strip() for line in file]
        
        not_in_genes=([ i for i in Odata.var_names if i not in genes_from_file ]) # 找出不在基因列表中的基因
        print("not on the genes lsts: \n")
        print(not_in_genes)
        print("\n")

        in_substr=[ i for i in not_in_genes if any([ i in j for j in genes_from_file])]
        print("match sub of the genes list: \n")
        print(in_substr)
        print("\n")

        for i in in_substr:
            print(f"process: {i}")
            out = list(np.array(genes_from_file)[[i in j for j in genes_from_file]])
            print(f"match to: {out}")
            if out:
                Odata.var.rename(index={i: out[0]}, inplace=True)

        complement = list(set(not_in_genes) - set(in_substr))
        print("\n complement: \n", complement, "\n")

        print("********************************************************************** \n")

        for k in complement:
            print(f"process: {k}")
            if "_" in k:
                print("***********************************")
                parts = k.split("_")
                substr=[ i for i in parts if any([ i in j for j in genes_from_file])]
                print(" match to the genes list:")
                print(substr)
                
                for i in substr:
                    print(f"for: {i}")
                    # 首先查找完全匹配的基因
                    exact_match = [j for j in genes_from_file if i == j]
                    if exact_match:
                        out = exact_match
                    else:
                        # 如果没有完全匹配的，再查找部分匹配的基因
                        out = [j for j in genes_from_file if i in j]
                    
                    print(f"match to: {out}")
                    if out:
                        Odata.var.rename(index={i: out[0]}, inplace=True)
                        print(f"remove: {k}, use {out[0]} represents {k}")
                        complement.remove(k)
                        break
                    print("************************")
                print("***********************************")
        
        print("\n complement: \n", complement, "\n")
                
                


        


        # in_substr=[ i for i in genes_from_file if any([ i in j for j in complement])]
        # for i in in_substr:
        #     print(f"process: {i}")
        #     out = list(np.array(complement)[[i in j for j in complement]])
        #     print(f"match to: {out}")

        

        return Odata

# %%
Odata_train_matched = matchGenes(Odata_train)
# Out:
# not on the genes lsts:
#
# ['CKMT1A_CKMT1B', 'DEFA1_DEFA1B', 'PNLIPRP2', 'IL3RA', 'NTproBNP', 'MICB_MICA', 'SIGLEC5', 'SARG', 'SPACA5_SPACA5B', 'PALM2', 'HCG22', 'IL12A_IL12B', 'GPR15L', 'FHIP2A', 'GATD3', 'FUT3_FUT5', 'MENT', 'KIR2DL2', 'KIR2DS4', 'LEG1', 'LILRA3', 'LGALS7_LGALS7B', 'BTNL10', 'BOLA2_BOLA2B', 'BAP18', 'CD99', 'CERT', 'WARS', 'AMY1A_AMY1B_AMY1C', 'AKR7L', 'ANP32C', 'DEFB103A_DEFB103B', 'DEFB4A_DEFB4B', 'DEFB104A_DEFB104B', 'CTAG1A_CTAG1B', 'CSF2RA', 'CGB3_CGB5_CGB8', 'EBI3_IL27']
#
#
# match sub of the genes list:
#
# ['IL3RA', 'SIGLEC5', 'PALM2', 'GATD3', 'CD99', 'CERT', 'WARS', 'CSF2RA']
#
#
# process: IL3RA
# match to: ['IL3RA_ENSG00000185291']
# process: SIGLEC5
# match to: ['SIGLEC5_ENSG00000268500', 'SIGLEC5_ENSG00000105501']
# process: PALM2
# match to: ['PALM2AKAP2']
# process: GATD3
# match to: ['GATD3A', 'GATD3B']
# process: CD99
# match to: ['CD99_ENSG00000002586', 'CD99L2']
# process: CERT
# match to: ['CERT1']
# process: WARS
# match to: ['WARS2-IT1', 'WARS2', 'WARS1', 'WARS2-AS1']
# process: CSF2RA
# match to: ['CSF2RA_ENSG00000198223']
#
#  complement:
#  ['HCG22', 'EBI3_IL27', 'MICB_MICA', 'GPR15L', 'PNLIPRP2', 'CKMT1A_CKMT1B', 'SARG', 'DEFB104A_DEFB104B', 'LEG1', 'CTAG1A_CTAG1B', 'LGALS7_LGALS7B', 'IL12A_IL12B', 'LILRA3', 'DEFB103A_DEFB103B', 'ANP32C', 'CGB3_CGB5_CGB8', 'MENT', 'NTproBNP', 'BTNL10', 'SPACA5_SPACA5B', 'AKR7L', 'AMY1A_AMY1B_AMY1C', 'BOLA2_BOLA2B', 'DEFA1_DEFA1B', 'DEFB4A_DEFB4B', 'KIR2DS4', 'FUT3_FUT5', 'FHIP2A', 'BAP18', 'KIR2DL2']
#
# **********************************************************************
#
# process: HCG22
# process: EBI3_IL27
# ***********************************
#  match to the genes list:
# ['EBI3', 'IL27']
# for: EBI3
# match to: ['EBI3']
# remove: EBI3_IL27, use EBI3 represents EBI3_IL27
# ***********************************
# process: GPR15L
# process: PNLIPRP2
# process: CKMT1A_CKMT1B
# ***********************************
#  match to the genes list:
# ['CKMT1A', 'CKMT1B']
# for: CKMT1A
# match to: ['CKMT1A']
# remove: CKMT1A_CKMT1B, use CKMT1A represents CKMT1A_CKMT1B
# ***********************************
# process: DEFB104A_DEFB104B
# ***********************************
#  match to the genes list:
# ['DEFB104A', 'DEFB104B']
# for: DEFB104A
# match to: ['DEFB104A']
# remove: DEFB104A_DEFB104B, use DEFB104A represents DEFB104A_DEFB104B
# ***********************************
# process: CTAG1A_CTAG1B
# ***********************************
#  match to the genes list:
# ['CTAG1A', 'CTAG1B']
# for: CTAG1A
# match to: ['CTAG1A']
# remove: CTAG1A_CTAG1B, use CTAG1A represents CTAG1A_CTAG1B
# ***********************************
# process: IL12A_IL12B
# ***********************************
#  match to the genes list:
# ['IL12A', 'IL12B']
# for: IL12A
# match to: ['IL12A']
# remove: IL12A_IL12B, use IL12A represents IL12A_IL12B
# ***********************************
# process: DEFB103A_DEFB103B
# ***********************************
#  match to the genes list:
# ['DEFB103A', 'DEFB103B']
# for: DEFB103A
# match to: ['DEFB103A']
# remove: DEFB103A_DEFB103B, use DEFB103A represents DEFB103A_DEFB103B
# ***********************************
# process: CGB3_CGB5_CGB8
# ***********************************
#  match to the genes list:
# ['CGB3', 'CGB5', 'CGB8']
# for: CGB3
# match to: ['CGB3']
# remove: CGB3_CGB5_CGB8, use CGB3 represents CGB3_CGB5_CGB8
# ***********************************
# process: NTproBNP
# process: BTNL10
# process: SPACA5_SPACA5B
# ***********************************
#  match to the genes list:
# ['SPACA5', 'SPACA5B']
# for: SPACA5
# match to: ['SPACA5']
# remove: SPACA5_SPACA5B, use SPACA5 represents SPACA5_SPACA5B
# ***********************************
# process: AMY1A_AMY1B_AMY1C
# ***********************************
#  match to the genes list:
# ['AMY1A', 'AMY1B', 'AMY1C']
# for: AMY1A
# match to: ['AMY1A']
# remove: AMY1A_AMY1B_AMY1C, use AMY1A represents AMY1A_AMY1B_AMY1C
# ***********************************
# process: DEFA1_DEFA1B
# ***********************************
#  match to the genes list:
# ['DEFA1', 'DEFA1B']
# for: DEFA1
# match to: ['DEFA1']
# remove: DEFA1_DEFA1B, use DEFA1 represents DEFA1_DEFA1B
# ***********************************
# process: KIR2DS4
# process: FUT3_FUT5
# ***********************************
#  match to the genes list:
# ['FUT3', 'FUT5']
# for: FUT3
# match to: ['FUT3']
# remove: FUT3_FUT5, use FUT3 represents FUT3_FUT5
# ***********************************
# process: BAP18
# process: KIR2DL2
#
#  complement:
#  ['HCG22', 'MICB_MICA', 'GPR15L', 'PNLIPRP2', 'SARG', 'LEG1', 'LGALS7_LGALS7B', 'LILRA3', 'ANP32C', 'MENT', 'NTproBNP', 'BTNL10', 'AKR7L', 'BOLA2_BOLA2B', 'DEFB4A_DEFB4B', 'KIR2DS4', 'FHIP2A', 'BAP18', 'KIR2DL2']

# %%
Odata_test_matched = matchGenes(Odata_test)
# Out:
# not on the genes lsts:
#
# ['CKMT1A_CKMT1B', 'DEFA1_DEFA1B', 'PNLIPRP2', 'IL3RA', 'NTproBNP', 'MICB_MICA', 'SIGLEC5', 'SARG', 'SPACA5_SPACA5B', 'PALM2', 'HCG22', 'IL12A_IL12B', 'GPR15L', 'FHIP2A', 'GATD3', 'FUT3_FUT5', 'MENT', 'KIR2DL2', 'KIR2DS4', 'LEG1', 'LILRA3', 'LGALS7_LGALS7B', 'BTNL10', 'BOLA2_BOLA2B', 'BAP18', 'CD99', 'CERT', 'WARS', 'AMY1A_AMY1B_AMY1C', 'AKR7L', 'ANP32C', 'DEFB103A_DEFB103B', 'DEFB4A_DEFB4B', 'DEFB104A_DEFB104B', 'CTAG1A_CTAG1B', 'CSF2RA', 'CGB3_CGB5_CGB8', 'EBI3_IL27']
#
#
# match sub of the genes list:
#
# ['IL3RA', 'SIGLEC5', 'PALM2', 'GATD3', 'CD99', 'CERT', 'WARS', 'CSF2RA']
#
#
# process: IL3RA
# match to: ['IL3RA_ENSG00000185291']
# process: SIGLEC5
# match to: ['SIGLEC5_ENSG00000268500', 'SIGLEC5_ENSG00000105501']
# process: PALM2
# match to: ['PALM2AKAP2']
# process: GATD3
# match to: ['GATD3A', 'GATD3B']
# process: CD99
# match to: ['CD99_ENSG00000002586', 'CD99L2']
# process: CERT
# match to: ['CERT1']
# process: WARS
# match to: ['WARS2-IT1', 'WARS2', 'WARS1', 'WARS2-AS1']
# process: CSF2RA
# match to: ['CSF2RA_ENSG00000198223']
#
#  complement:
#  ['HCG22', 'EBI3_IL27', 'MICB_MICA', 'GPR15L', 'PNLIPRP2', 'CKMT1A_CKMT1B', 'SARG', 'DEFB104A_DEFB104B', 'LEG1', 'CTAG1A_CTAG1B', 'LGALS7_LGALS7B', 'IL12A_IL12B', 'LILRA3', 'DEFB103A_DEFB103B', 'ANP32C', 'CGB3_CGB5_CGB8', 'MENT', 'NTproBNP', 'BTNL10', 'SPACA5_SPACA5B', 'AKR7L', 'AMY1A_AMY1B_AMY1C', 'BOLA2_BOLA2B', 'DEFA1_DEFA1B', 'DEFB4A_DEFB4B', 'KIR2DS4', 'FUT3_FUT5', 'FHIP2A', 'BAP18', 'KIR2DL2']
#
# **********************************************************************
#
# process: HCG22
# process: EBI3_IL27
# ***********************************
#  match to the genes list:
# ['EBI3', 'IL27']
# for: EBI3
# match to: ['EBI3']
# remove: EBI3_IL27, use EBI3 represents EBI3_IL27
# ***********************************
# process: GPR15L
# process: PNLIPRP2
# process: CKMT1A_CKMT1B
# ***********************************
#  match to the genes list:
# ['CKMT1A', 'CKMT1B']
# for: CKMT1A
# match to: ['CKMT1A']
# remove: CKMT1A_CKMT1B, use CKMT1A represents CKMT1A_CKMT1B
# ***********************************
# process: DEFB104A_DEFB104B
# ***********************************
#  match to the genes list:
# ['DEFB104A', 'DEFB104B']
# for: DEFB104A
# match to: ['DEFB104A']
# remove: DEFB104A_DEFB104B, use DEFB104A represents DEFB104A_DEFB104B
# ***********************************
# process: CTAG1A_CTAG1B
# ***********************************
#  match to the genes list:
# ['CTAG1A', 'CTAG1B']
# for: CTAG1A
# match to: ['CTAG1A']
# remove: CTAG1A_CTAG1B, use CTAG1A represents CTAG1A_CTAG1B
# ***********************************
# process: IL12A_IL12B
# ***********************************
#  match to the genes list:
# ['IL12A', 'IL12B']
# for: IL12A
# match to: ['IL12A']
# remove: IL12A_IL12B, use IL12A represents IL12A_IL12B
# ***********************************
# process: DEFB103A_DEFB103B
# ***********************************
#  match to the genes list:
# ['DEFB103A', 'DEFB103B']
# for: DEFB103A
# match to: ['DEFB103A']
# remove: DEFB103A_DEFB103B, use DEFB103A represents DEFB103A_DEFB103B
# ***********************************
# process: CGB3_CGB5_CGB8
# ***********************************
#  match to the genes list:
# ['CGB3', 'CGB5', 'CGB8']
# for: CGB3
# match to: ['CGB3']
# remove: CGB3_CGB5_CGB8, use CGB3 represents CGB3_CGB5_CGB8
# ***********************************
# process: NTproBNP
# process: BTNL10
# process: SPACA5_SPACA5B
# ***********************************
#  match to the genes list:
# ['SPACA5', 'SPACA5B']
# for: SPACA5
# match to: ['SPACA5']
# remove: SPACA5_SPACA5B, use SPACA5 represents SPACA5_SPACA5B
# ***********************************
# process: AMY1A_AMY1B_AMY1C
# ***********************************
#  match to the genes list:
# ['AMY1A', 'AMY1B', 'AMY1C']
# for: AMY1A
# match to: ['AMY1A']
# remove: AMY1A_AMY1B_AMY1C, use AMY1A represents AMY1A_AMY1B_AMY1C
# ***********************************
# process: DEFA1_DEFA1B
# ***********************************
#  match to the genes list:
# ['DEFA1', 'DEFA1B']
# for: DEFA1
# match to: ['DEFA1']
# remove: DEFA1_DEFA1B, use DEFA1 represents DEFA1_DEFA1B
# ***********************************
# process: KIR2DS4
# process: FUT3_FUT5
# ***********************************
#  match to the genes list:
# ['FUT3', 'FUT5']
# for: FUT3
# match to: ['FUT3']
# remove: FUT3_FUT5, use FUT3 represents FUT3_FUT5
# ***********************************
# process: BAP18
# process: KIR2DL2
#
#  complement:
#  ['HCG22', 'MICB_MICA', 'GPR15L', 'PNLIPRP2', 'SARG', 'LEG1', 'LGALS7_LGALS7B', 'LILRA3', 'ANP32C', 'MENT', 'NTproBNP', 'BTNL10', 'AKR7L', 'BOLA2_BOLA2B', 'DEFB4A_DEFB4B', 'KIR2DS4', 'FHIP2A', 'BAP18', 'KIR2DL2']

# %%
# with open('/data/mr423/project/gene2idx.txt', newline='') as f:
# # with open('/data/mr423/project/keys.txt', newline='') as f:
#     reader = csv.reader(f)
#     genes = list(reader)

# # print(type(genes))
    
# genes =  [ a.replace("'", "").replace(" ", "") for a in genes[0] ]
# # print(type(genes))
# # print(genes)

# not_in_genes=([ a for a in Odata.var_names if a not in genes ]) # 找出不在基因列表中的基因
# print("not_in_genes \n :",not_in_genes)
# '''
# 从 not_in_genes 列表中找出那些作为子字符串存在于 genes 列表中的基因名称，并将它们存储在 notin_substr 列表中。
# 样可以帮助我们识别那些虽然不完全匹配但在某种程度上与已有基因相关的基因名称
# '''
# notin_substr=[ a for a in not_in_genes if any([ a in b for b in genes])]
# notin_substr

# %%
# '''
# 将 notin_substr 列表中的基因子串替换为它们在 genes 列表中匹配的完整基因名称，并在 Odata.var 数据框中重命名这些基因
# '''
# for a in notin_substr:
#     print(a)
#     out=(list(np.array(genes)[[ a in b for b in genes]]))
#     Odata.var.rename(index={a: out[0]}, inplace=True)

# %%
gene_name = Odata_train_matched.var_names.astype("category")

Odata_train_matched.var["gene_name"] = gene_name
Odata_test_matched.var["gene_name"] = gene_name

# %% [markdown]
# ## Sample data format

# %%
data_dir = "../tutorials/data/Multiple_Sclerosis_dataset/ms/c_data.h5ad"
adata = sc.read(data_dir)

# %%
Odata.obs = pd.DataFrame(index=Odata.obs.index, columns=adata.obs.columns)
Odata.obs[adata.obs.columns]=np.nan
Odata.shape
# Out:
# (2000, 2917)

# %% [markdown]
# ### initial data

# %%
Odata.obs
# Out:
#          Sample Characteristic[organism]  \
# Id
# 1000221                              NaN
# 1000326                              NaN
# 1000662                              NaN
# 1000823                              NaN
# 1000945                              NaN
# ...                                  ...
# 1237356                              NaN
# 1237469                              NaN
# 1237481                              NaN
# 1237497                              NaN
# 1237593                              NaN
#
#          Sample Characteristic Ontology Term[organism]  \
# Id
# 1000221                                            NaN
# 1000326                                            NaN
# 1000662                                            NaN
# 1000823                                            NaN
# 1000945                                            NaN
# ...                                                ...
# 1237356                                            NaN
# 1237469                                            NaN
# 1237481                                            NaN
# 1237497                                            NaN
# 1237593                                            NaN
#
#          Sample Characteristic[individual]  \
# Id
# 1000221                                NaN
# 1000326                                NaN
# 1000662                                NaN
# 1000823                                NaN
# 1000945                                NaN
# ...                                    ...
# 1237356                                NaN
# 1237469                                NaN
# 1237481                                NaN
# 1237497                                NaN
# 1237593                                NaN
#
#          Sample Characteristic Ontology Term[individual]  \
# Id
# 1000221                                              NaN
# 1000326                                              NaN
# 1000662                                              NaN
# 1000823                                              NaN
# 1000945                                              NaN
# ...                                                  ...
# 1237356                                              NaN
# 1237469                                              NaN
# 1237481                                              NaN
# 1237497                                              NaN
# 1237593                                              NaN
#
#          Sample Characteristic[sex]  Sample Characteristic Ontology Term[sex]  \
# Id
# 1000221                         NaN                                       NaN
# 1000326                         NaN                                       NaN
# 1000662                         NaN                                       NaN
# 1000823                         NaN                                       NaN
# 1000945                         NaN                                       NaN
# ...                             ...                                       ...
# 1237356                         NaN                                       NaN
# 1237469                         NaN                                       NaN
# 1237481                         NaN                                       NaN
# 1237497                         NaN                                       NaN
# 1237593                         NaN                                       NaN
#
#          Sample Characteristic[age]  Sample Characteristic Ontology Term[age]  \
# Id
# 1000221                         NaN                                       NaN
# 1000326                         NaN                                       NaN
# 1000662                         NaN                                       NaN
# 1000823                         NaN                                       NaN
# 1000945                         NaN                                       NaN
# ...                             ...                                       ...
# 1237356                         NaN                                       NaN
# 1237469                         NaN                                       NaN
# 1237481                         NaN                                       NaN
# 1237497                         NaN                                       NaN
# 1237593                         NaN                                       NaN
#
#          Sample Characteristic[developmental stage]  \
# Id
# 1000221                                         NaN
# 1000326                                         NaN
# 1000662                                         NaN
# 1000823                                         NaN
# 1000945                                         NaN
# ...                                             ...
# 1237356                                         NaN
# 1237469                                         NaN
# 1237481                                         NaN
# 1237497                                         NaN
# 1237593                                         NaN
#
#          Sample Characteristic Ontology Term[developmental stage]  ...  \
# Id                                                                 ...
# 1000221                                                NaN         ...
# 1000326                                                NaN         ...
# 1000662                                                NaN         ...
# 1000823                                                NaN         ...
# 1000945                                                NaN         ...
# ...                                                    ...         ...
# 1237356                                                NaN         ...
# 1237469                                                NaN         ...
# 1237481                                                NaN         ...
# 1237497                                                NaN         ...
# 1237593                                                NaN         ...
#
#          Factor Value[disease]  Factor Value Ontology Term[disease]  \
# Id
# 1000221                    NaN                                  NaN
# 1000326                    NaN                                  NaN
# 1000662                    NaN                                  NaN
# 1000823                    NaN                                  NaN
# 1000945                    NaN                                  NaN
# ...                        ...                                  ...
# 1237356                    NaN                                  NaN
# 1237469                    NaN                                  NaN
# 1237481                    NaN                                  NaN
# 1237497                    NaN                                  NaN
# 1237593                    NaN                                  NaN
#
#          Factor Value[sampling site]  \
# Id
# 1000221                          NaN
# 1000326                          NaN
# 1000662                          NaN
# 1000823                          NaN
# 1000945                          NaN
# ...                              ...
# 1237356                          NaN
# 1237469                          NaN
# 1237481                          NaN
# 1237497                          NaN
# 1237593                          NaN
#
#          Factor Value Ontology Term[sampling site]  \
# Id
# 1000221                                        NaN
# 1000326                                        NaN
# 1000662                                        NaN
# 1000823                                        NaN
# 1000945                                        NaN
# ...                                            ...
# 1237356                                        NaN
# 1237469                                        NaN
# 1237481                                        NaN
# 1237497                                        NaN
# 1237593                                        NaN
#
#          Factor Value[inferred cell type - ontology labels]  \
# Id
# 1000221                                                NaN
# 1000326                                                NaN
# 1000662                                                NaN
# 1000823                                                NaN
# 1000945                                                NaN
# ...                                                    ...
# 1237356                                                NaN
# 1237469                                                NaN
# 1237481                                                NaN
# 1237497                                                NaN
# 1237593                                                NaN
#
#          Factor Value Ontology Term[inferred cell type - ontology labels]  \
# Id
# 1000221                                                NaN
# 1000326                                                NaN
# 1000662                                                NaN
# 1000823                                                NaN
# 1000945                                                NaN
# ...                                                    ...
# 1237356                                                NaN
# 1237469                                                NaN
# 1237481                                                NaN
# 1237497                                                NaN
# 1237593                                                NaN
#
#          Factor Value[inferred cell type - authors labels]  \
# Id
# 1000221                                                NaN
# 1000326                                                NaN
# 1000662                                                NaN
# 1000823                                                NaN
# 1000945                                                NaN
# ...                                                    ...
# 1237356                                                NaN
# 1237469                                                NaN
# 1237481                                                NaN
# 1237497                                                NaN
# 1237593                                                NaN
#
#          Factor Value Ontology Term[inferred cell type - authors labels]  \
# Id
# 1000221                                                NaN
# 1000326                                                NaN
# 1000662                                                NaN
# 1000823                                                NaN
# 1000945                                                NaN
# ...                                                    ...
# 1237356                                                NaN
# 1237469                                                NaN
# 1237481                                                NaN
# 1237497                                                NaN
# 1237593                                                NaN
#
#          str_batch  celltype
# Id
# 1000221        NaN       NaN
# 1000326        NaN       NaN
# 1000662        NaN       NaN
# 1000823        NaN       NaN
# 1000945        NaN       NaN
# ...            ...       ...
# 1237356        NaN       NaN
# 1237469        NaN       NaN
# 1237481        NaN       NaN
# 1237497        NaN       NaN
# 1237593        NaN       NaN
#
# [2000 rows x 32 columns]

# %%
i = 0
for col in Odata.obs.columns:
    vvs = np.unique(Odata.obs[col].dropna())
    if len(vvs) == 0:
        i+=1
        print(f"列 {col} 全部都是 NA")
print(i)
# Out:
# 列 Sample Characteristic[organism] 全部都是 NA
# 列 Sample Characteristic Ontology Term[organism] 全部都是 NA
# 列 Sample Characteristic[individual] 全部都是 NA
# 列 Sample Characteristic Ontology Term[individual] 全部都是 NA
# 列 Sample Characteristic[sex] 全部都是 NA
# 列 Sample Characteristic Ontology Term[sex] 全部都是 NA
# 列 Sample Characteristic[age] 全部都是 NA
# 列 Sample Characteristic Ontology Term[age] 全部都是 NA
# 列 Sample Characteristic[developmental stage] 全部都是 NA
# 列 Sample Characteristic Ontology Term[developmental stage] 全部都是 NA
# 列 Sample Characteristic[organism part] 全部都是 NA
# 列 Sample Characteristic Ontology Term[organism part] 全部都是 NA
# 列 Sample Characteristic[sampling site] 全部都是 NA
# 列 Sample Characteristic Ontology Term[sampling site] 全部都是 NA
# 列 Sample Characteristic[disease] 全部都是 NA
# 列 Sample Characteristic Ontology Term[disease] 全部都是 NA
# 列 Sample Characteristic[organism status] 全部都是 NA
# 列 Sample Characteristic Ontology Term[organism status] 全部都是 NA
# 列 Sample Characteristic[cause of death] 全部都是 NA
# 列 Sample Characteristic Ontology Term[cause of death] 全部都是 NA
# 列 Sample Characteristic[clinical history] 全部都是 NA
# 列 Sample Characteristic Ontology Term[clinical history] 全部都是 NA
# 列 Factor Value[disease] 全部都是 NA
# 列 Factor Value Ontology Term[disease] 全部都是 NA
# 列 Factor Value[sampling site] 全部都是 NA
# 列 Factor Value Ontology Term[sampling site] 全部都是 NA
# 列 Factor Value[inferred cell type - ontology labels] 全部都是 NA
# 列 Factor Value Ontology Term[inferred cell type - ontology labels] 全部都是 NA
# 列 Factor Value[inferred cell type - authors labels] 全部都是 NA
# 列 Factor Value Ontology Term[inferred cell type - authors labels] 全部都是 NA
# 列 str_batch 全部都是 NA
# 列 celltype 全部都是 NA
# 32

# %%
Odata.obs.dtypes
# Out:
# Sample Characteristic[organism]                                     float64
# Sample Characteristic Ontology Term[organism]                       float64
# Sample Characteristic[individual]                                   float64
# Sample Characteristic Ontology Term[individual]                     float64
# Sample Characteristic[sex]                                          float64
# Sample Characteristic Ontology Term[sex]                            float64
# Sample Characteristic[age]                                          float64
# Sample Characteristic Ontology Term[age]                            float64
# Sample Characteristic[developmental stage]                          float64
# Sample Characteristic Ontology Term[developmental stage]            float64
# Sample Characteristic[organism part]                                float64
# Sample Characteristic Ontology Term[organism part]                  float64
# Sample Characteristic[sampling site]                                float64
# Sample Characteristic Ontology Term[sampling site]                  float64
# Sample Characteristic[disease]                                      float64
# Sample Characteristic Ontology Term[disease]                        float64
# Sample Characteristic[organism status]                              float64
# Sample Characteristic Ontology Term[organism status]                float64
# Sample Characteristic[cause of death]                               float64
# Sample Characteristic Ontology Term[cause of death]                 float64
# Sample Characteristic[clinical history]                             float64
# Sample Characteristic Ontology Term[clinical history]               float64
# Factor Value[disease]                                               float64
# Factor Value Ontology Term[disease]                                 float64
# Factor Value[sampling site]                                         float64
# Factor Value Ontology Term[sampling site]                           float64
# Factor Value[inferred cell type - ontology labels]                  float64
# Factor Value Ontology Term[inferred cell type - ontology labels]    float64
# Factor Value[inferred cell type - authors labels]                   float64
# Factor Value Ontology Term[inferred cell type - authors labels]     float64
# str_batch                                                           float64
# celltype                                                            float64
# dtype: object

# %% [markdown]
# ### set some data

# %%
# # 遍历 adata.obs 的每一列并处理
# for a in range(len(adata.obs.columns)):
#     vvs = np.unique(adata.obs.iloc[:, a].dropna())
#     if len(vvs) == 1:
#         # 将 Odata.obs 对应列显式转换为 adata.obs 对应列的类型
#         if adata.obs.iloc[:, a].dtype == object or isinstance(adata.obs.iloc[0, a], str):
            
#             Odata.obs.iloc[:, a] = Odata.obs.iloc[:, a].astype(object)
#         else:
#             Odata.obs.iloc[:, a] = Odata.obs.iloc[:, a].astype(adata.obs.iloc[:, a].dtype)
        
#         # 赋值为 adata.obs 中该列的第一个值
#         Odata.obs.iloc[:, a] = adata.obs.iloc[0, a]

# %%
i = 0
for col in Odata.obs.columns:
    vvs = np.unique(Odata.obs[col].dropna())
    if len(vvs) == 0:
        i+=1
        # print(f"列 {col} 全部都是 NA")
        print(f"Odata.obs.loc[:,'{col}']")
        # print(f"'{col}',")
print(i)
# Out:
# Odata.obs.loc[:,'Sample Characteristic[organism]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[organism]']
# Odata.obs.loc[:,'Sample Characteristic[individual]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[individual]']
# Odata.obs.loc[:,'Sample Characteristic[sex]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[sex]']
# Odata.obs.loc[:,'Sample Characteristic[age]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[age]']
# Odata.obs.loc[:,'Sample Characteristic[developmental stage]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[developmental stage]']
# Odata.obs.loc[:,'Sample Characteristic[organism part]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[organism part]']
# Odata.obs.loc[:,'Sample Characteristic[sampling site]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[sampling site]']
# Odata.obs.loc[:,'Sample Characteristic[disease]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[disease]']
# Odata.obs.loc[:,'Sample Characteristic[organism status]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[organism status]']
# Odata.obs.loc[:,'Sample Characteristic[cause of death]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[cause of death]']
# Odata.obs.loc[:,'Sample Characteristic[clinical history]']
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[clinical history]']
# Odata.obs.loc[:,'Factor Value[disease]']
# Odata.obs.loc[:,'Factor Value Ontology Term[disease]']
# Odata.obs.loc[:,'Factor Value[sampling site]']
# Odata.obs.loc[:,'Factor Value Ontology Term[sampling site]']
# Odata.obs.loc[:,'Factor Value[inferred cell type - ontology labels]']
# Odata.obs.loc[:,'Factor Value Ontology Term[inferred cell type - ontology labels]']
# Odata.obs.loc[:,'Factor Value[inferred cell type - authors labels]']
# Odata.obs.loc[:,'Factor Value Ontology Term[inferred cell type - authors labels]']
# Odata.obs.loc[:,'str_batch']
# Odata.obs.loc[:,'celltype']
# 32

# %% [markdown]
# ### set fake data

# %%
columns_to_convert = [
    'Sample Characteristic[organism]',
    'Sample Characteristic Ontology Term[organism]',
    'Sample Characteristic[individual]',
    'Sample Characteristic[sex]',
    'Sample Characteristic Ontology Term[sex]',
    'Sample Characteristic[age]',
    'Sample Characteristic[developmental stage]',
    'Sample Characteristic Ontology Term[developmental stage]',
    'Sample Characteristic[organism part]',
    'Sample Characteristic Ontology Term[organism part]',
    'Sample Characteristic[sampling site]',
    'Sample Characteristic Ontology Term[sampling site]',
    'Sample Characteristic[disease]',
    'Sample Characteristic Ontology Term[disease]',
    'Sample Characteristic[organism status]',
    'Sample Characteristic Ontology Term[organism status]',
    'Factor Value[disease]',
    'Factor Value Ontology Term[disease]',
    'Factor Value[sampling site]',
    'Factor Value Ontology Term[sampling site]',
    'Factor Value[inferred cell type - ontology labels]',
    'Factor Value Ontology Term[inferred cell type - ontology labels]',
    'Factor Value[inferred cell type - authors labels]',
    'Factor Value Ontology Term[inferred cell type - authors labels]',
    'str_batch',
    'celltype',
]

for column in columns_to_convert:
    Odata.obs[column] = Odata.obs[column].astype(str)

# Odata.obs.loc[:,'Sample Characteristic[organism]'] = 'Homo sapiens'
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[organism]'] = 'http://purl.obolibrary.org/obo/NCBITaxon_9606'
# Odata.obs.loc[:,'Sample Characteristic[individual]'] = Odata.obs.index
# Odata.obs.loc[:,'Sample Characteristic[sex]']='female'
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[sex]']='http://purl.obolibrary.org/obo/PATO_0000383'
# Odata.obs.loc[:,'Sample Characteristic[age]']='60 year'
# Odata.obs.loc[:,'Sample Characteristic[developmental stage]'] = 'human adult stage'
# Odata.obs.loc[:,'Sample Characteristic[sampling site]']='blood plasma'
# Odata.obs.loc[:,'Sample Characteristic Ontology Term[sampling site]']='http://purl.obolibrary.org/obo/UBERON:0001969'
# Odata.obs.loc[:,'Factor Value[sampling site]']='http://purl.obolibrary.org/obo/UBERON:0001969'
# Odata.obs.loc[:,'Factor Value[inferred cell type - authors labels]'] = 'fake cell'
# Odata.obs.loc[:,'str_batch'] = '3'



Odata.obs.loc[:,'Sample Characteristic[organism]'] = 'Homo sapiens'
Odata.obs.loc[:,'Sample Characteristic Ontology Term[organism]'] = 'http://purl.obolibrary.org/obo/NCBITaxon_9606'
Odata.obs.loc[:,'Sample Characteristic[individual]']= Odata.obs.index
Odata.obs.loc[:,'Sample Characteristic[sex]']= 'female'
Odata.obs.loc[:,'Sample Characteristic Ontology Term[sex]'] ='http://purl.obolibrary.org/obo/PATO_0000383'
Odata.obs.loc[:,'Sample Characteristic[age]'] = '60 year'
Odata.obs.loc[:,'Sample Characteristic[developmental stage]'] ='human adult stage'
Odata.obs.loc[:,'Sample Characteristic Ontology Term[developmental stage]'] ='http://purl.obolibrary.org/obo/HsapDv_0000087'
Odata.obs.loc[:,'Sample Characteristic[organism part]'] = 'blood'
Odata.obs.loc[:,'Sample Characteristic Ontology Term[organism part]'] ='http://purl.obolibrary.org/obo/UBERON_0000955'
Odata.obs.loc[:,'Sample Characteristic[sampling site]'] ='blood plasma'
Odata.obs.loc[:,'Sample Characteristic Ontology Term[sampling site]'] = 'http://purl.obolibrary.org/obo/UBERON:0001969'
Odata.obs.loc[:,'Sample Characteristic[disease]'] = 'normal'
Odata.obs.loc[:,'Sample Characteristic Ontology Term[disease]'] ='http://purl.obolibrary.org/obo/PATO_0000461'
Odata.obs.loc[:,'Sample Characteristic[organism status]'] = 'dead'
Odata.obs.loc[:,'Sample Characteristic Ontology Term[organism status]'] ='http://purl.obolibrary.org/obo/PATO_0001422'
Odata.obs.loc[:,'Factor Value[disease]'] ='normal'
Odata.obs.loc[:,'Factor Value Ontology Term[disease]'] = 'http://purl.obolibrary.org/obo/PATO_0000461'
Odata.obs.loc[:,'Factor Value[sampling site]'] = 'blood plasma'
Odata.obs.loc[:,'Factor Value Ontology Term[sampling site]']
Odata.obs.loc[:,'Factor Value[inferred cell type - ontology labels]']
Odata.obs.loc[:,'Factor Value Ontology Term[inferred cell type - ontology labels]']
Odata.obs.loc[:,'Factor Value[inferred cell type - authors labels]']
Odata.obs.loc[:,'Factor Value Ontology Term[inferred cell type - authors labels]']
Odata.obs.loc[:,'str_batch'] ='3'
# Odata.obs.loc[:,'celltype'] = '

# %%
Odata.obs
# Out:
#         Sample Characteristic[organism]  \
# Id
# 1000221                    Homo sapiens
# 1000326                    Homo sapiens
# 1000662                    Homo sapiens
# 1000823                    Homo sapiens
# 1000945                    Homo sapiens
# ...                                 ...
# 1237356                    Homo sapiens
# 1237469                    Homo sapiens
# 1237481                    Homo sapiens
# 1237497                    Homo sapiens
# 1237593                    Homo sapiens
#
#          Sample Characteristic Ontology Term[organism]  \
# Id
# 1000221  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1000326  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1000662  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1000823  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1000945  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ...                                                ...
# 1237356  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1237469  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1237481  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1237497  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1237593  http://purl.obolibrary.org/obo/NCBITaxon_9606
#
#         Sample Characteristic[individual]  \
# Id
# 1000221                           1000221
# 1000326                           1000326
# 1000662                           1000662
# 1000823                           1000823
# 1000945                           1000945
# ...                                   ...
# 1237356                           1237356
# 1237469                           1237469
# 1237481                           1237481
# 1237497                           1237497
# 1237593                           1237593
#
#          Sample Characteristic Ontology Term[individual]  \
# Id
# 1000221                                              NaN
# 1000326                                              NaN
# 1000662                                              NaN
# 1000823                                              NaN
# 1000945                                              NaN
# ...                                                  ...
# 1237356                                              NaN
# 1237469                                              NaN
# 1237481                                              NaN
# 1237497                                              NaN
# 1237593                                              NaN
#
#         Sample Characteristic[sex]  \
# Id
# 1000221                     female
# 1000326                     female
# 1000662                     female
# 1000823                     female
# 1000945                     female
# ...                            ...
# 1237356                     female
# 1237469                     female
# 1237481                     female
# 1237497                     female
# 1237593                     female
#
#             Sample Characteristic Ontology Term[sex]  \
# Id
# 1000221  http://purl.obolibrary.org/obo/PATO_0000383
# 1000326  http://purl.obolibrary.org/obo/PATO_0000383
# 1000662  http://purl.obolibrary.org/obo/PATO_0000383
# 1000823  http://purl.obolibrary.org/obo/PATO_0000383
# 1000945  http://purl.obolibrary.org/obo/PATO_0000383
# ...                                              ...
# 1237356  http://purl.obolibrary.org/obo/PATO_0000383
# 1237469  http://purl.obolibrary.org/obo/PATO_0000383
# 1237481  http://purl.obolibrary.org/obo/PATO_0000383
# 1237497  http://purl.obolibrary.org/obo/PATO_0000383
# 1237593  http://purl.obolibrary.org/obo/PATO_0000383
#
#         Sample Characteristic[age]  Sample Characteristic Ontology Term[age]  \
# Id
# 1000221                    60 year                                       NaN
# 1000326                    60 year                                       NaN
# 1000662                    60 year                                       NaN
# 1000823                    60 year                                       NaN
# 1000945                    60 year                                       NaN
# ...                            ...                                       ...
# 1237356                    60 year                                       NaN
# 1237469                    60 year                                       NaN
# 1237481                    60 year                                       NaN
# 1237497                    60 year                                       NaN
# 1237593                    60 year                                       NaN
#
#         Sample Characteristic[developmental stage]  \
# Id
# 1000221                          human adult stage
# 1000326                          human adult stage
# 1000662                          human adult stage
# 1000823                          human adult stage
# 1000945                          human adult stage
# ...                                            ...
# 1237356                          human adult stage
# 1237469                          human adult stage
# 1237481                          human adult stage
# 1237497                          human adult stage
# 1237593                          human adult stage
#
#         Sample Characteristic Ontology Term[developmental stage]  ...  \
# Id                                                                ...
# 1000221      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1000326      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1000662      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1000823      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1000945      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# ...                                                    ...        ...
# 1237356      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1237469      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1237481      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1237497      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1237593      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
#
#         Factor Value[disease]          Factor Value Ontology Term[disease]  \
# Id
# 1000221                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1000326                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1000662                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1000823                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1000945                normal  http://purl.obolibrary.org/obo/PATO_0000461
# ...                       ...                                          ...
# 1237356                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1237469                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1237481                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1237497                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1237593                normal  http://purl.obolibrary.org/obo/PATO_0000461
#
#         Factor Value[sampling site] Factor Value Ontology Term[sampling site]  \
# Id
# 1000221                blood plasma                                       nan
# 1000326                blood plasma                                       nan
# 1000662                blood plasma                                       nan
# 1000823                blood plasma                                       nan
# 1000945                blood plasma                                       nan
# ...                             ...                                       ...
# 1237356                blood plasma                                       nan
# 1237469                blood plasma                                       nan
# 1237481                blood plasma                                       nan
# 1237497                blood plasma                                       nan
# 1237593                blood plasma                                       nan
#
#         Factor Value[inferred cell type - ontology labels]  \
# Id
# 1000221                                                nan
# 1000326                                                nan
# 1000662                                                nan
# 1000823                                                nan
# 1000945                                                nan
# ...                                                    ...
# 1237356                                                nan
# 1237469                                                nan
# 1237481                                                nan
# 1237497                                                nan
# 1237593                                                nan
#
#         Factor Value Ontology Term[inferred cell type - ontology labels]  \
# Id
# 1000221                                                nan
# 1000326                                                nan
# 1000662                                                nan
# 1000823                                                nan
# 1000945                                                nan
# ...                                                    ...
# 1237356                                                nan
# 1237469                                                nan
# 1237481                                                nan
# 1237497                                                nan
# 1237593                                                nan
#
#         Factor Value[inferred cell type - authors labels]  \
# Id
# 1000221                                               nan
# 1000326                                               nan
# 1000662                                               nan
# 1000823                                               nan
# 1000945                                               nan
# ...                                                   ...
# 1237356                                               nan
# 1237469                                               nan
# 1237481                                               nan
# 1237497                                               nan
# 1237593                                               nan
#
#         Factor Value Ontology Term[inferred cell type - authors labels]  \
# Id
# 1000221                                                nan
# 1000326                                                nan
# 1000662                                                nan
# 1000823                                                nan
# 1000945                                                nan
# ...                                                    ...
# 1237356                                                nan
# 1237469                                                nan
# 1237481                                                nan
# 1237497                                                nan
# 1237593                                                nan
#
#          str_batch  celltype
# Id
# 1000221          3       nan
# 1000326          3       nan
# 1000662          3       nan
# 1000823          3       nan
# 1000945          3       nan
# ...            ...       ...
# 1237356          3       nan
# 1237469          3       nan
# 1237481          3       nan
# 1237497          3       nan
# 1237593          3       nan
#
# [2000 rows x 32 columns]

# %%
Odata.obs.dtypes
# Out:
# Sample Characteristic[organism]                                      object
# Sample Characteristic Ontology Term[organism]                        object
# Sample Characteristic[individual]                                    object
# Sample Characteristic Ontology Term[individual]                     float64
# Sample Characteristic[sex]                                           object
# Sample Characteristic Ontology Term[sex]                             object
# Sample Characteristic[age]                                           object
# Sample Characteristic Ontology Term[age]                            float64
# Sample Characteristic[developmental stage]                           object
# Sample Characteristic Ontology Term[developmental stage]             object
# Sample Characteristic[organism part]                                 object
# Sample Characteristic Ontology Term[organism part]                   object
# Sample Characteristic[sampling site]                                 object
# Sample Characteristic Ontology Term[sampling site]                   object
# Sample Characteristic[disease]                                       object
# Sample Characteristic Ontology Term[disease]                         object
# Sample Characteristic[organism status]                               object
# Sample Characteristic Ontology Term[organism status]                 object
# Sample Characteristic[cause of death]                               float64
# Sample Characteristic Ontology Term[cause of death]                 float64
# Sample Characteristic[clinical history]                             float64
# Sample Characteristic Ontology Term[clinical history]               float64
# Factor Value[disease]                                                object
# Factor Value Ontology Term[disease]                                  object
# Factor Value[sampling site]                                          object
# Factor Value Ontology Term[sampling site]                            object
# Factor Value[inferred cell type - ontology labels]                   object
# Factor Value Ontology Term[inferred cell type - ontology labels]     object
# Factor Value[inferred cell type - authors labels]                    object
# Factor Value Ontology Term[inferred cell type - authors labels]      object
# str_batch                                                            object
# celltype                                                             object
# dtype: object

# %%
columns_to_convert = [
    'Sample Characteristic[organism]',
    'Sample Characteristic Ontology Term[organism]',
    'Sample Characteristic[individual]',
    'Sample Characteristic[sex]',
    'Sample Characteristic Ontology Term[sex]',
    'Sample Characteristic[age]',
    'Sample Characteristic[developmental stage]',
    'Sample Characteristic Ontology Term[developmental stage]',
    'Sample Characteristic[organism part]',
    'Sample Characteristic Ontology Term[organism part]',
    'Sample Characteristic[sampling site]',
    'Sample Characteristic Ontology Term[sampling site]',
    'Sample Characteristic[disease]',
    'Sample Characteristic Ontology Term[disease]',
    'Sample Characteristic[organism status]',
    'Sample Characteristic Ontology Term[organism status]',
    'Factor Value[disease]',
    'Factor Value Ontology Term[disease]',
    'Factor Value[sampling site]',
    'Factor Value Ontology Term[sampling site]',
    'Factor Value[inferred cell type - ontology labels]',
    'Factor Value Ontology Term[inferred cell type - ontology labels]',
    'Factor Value[inferred cell type - authors labels]',
    'Factor Value Ontology Term[inferred cell type - authors labels]',
    'str_batch',
    'celltype',
]

for column in columns_to_convert:
    Odata.obs[column] = Odata.obs[column].astype('category')

# %%
Odata.obs.dtypes
# Out:
# Sample Characteristic[organism]                                     category
# Sample Characteristic Ontology Term[organism]                       category
# Sample Characteristic[individual]                                   category
# Sample Characteristic Ontology Term[individual]                      float64
# Sample Characteristic[sex]                                          category
# Sample Characteristic Ontology Term[sex]                            category
# Sample Characteristic[age]                                          category
# Sample Characteristic Ontology Term[age]                             float64
# Sample Characteristic[developmental stage]                          category
# Sample Characteristic Ontology Term[developmental stage]            category
# Sample Characteristic[organism part]                                category
# Sample Characteristic Ontology Term[organism part]                  category
# Sample Characteristic[sampling site]                                category
# Sample Characteristic Ontology Term[sampling site]                  category
# Sample Characteristic[disease]                                      category
# Sample Characteristic Ontology Term[disease]                        category
# Sample Characteristic[organism status]                              category
# Sample Characteristic Ontology Term[organism status]                category
# Sample Characteristic[cause of death]                                float64
# Sample Characteristic Ontology Term[cause of death]                  float64
# Sample Characteristic[clinical history]                              float64
# Sample Characteristic Ontology Term[clinical history]                float64
# Factor Value[disease]                                               category
# Factor Value Ontology Term[disease]                                 category
# Factor Value[sampling site]                                         category
# Factor Value Ontology Term[sampling site]                           category
# Factor Value[inferred cell type - ontology labels]                  category
# Factor Value Ontology Term[inferred cell type - ontology labels]    category
# Factor Value[inferred cell type - authors labels]                   category
# Factor Value Ontology Term[inferred cell type - authors labels]     category
# str_batch                                                           category
# celltype                                                            category
# dtype: object

# %%
Odata.obs
# Out:
#         Sample Characteristic[organism]  \
# Id
# 1000221                    Homo sapiens
# 1000326                    Homo sapiens
# 1000662                    Homo sapiens
# 1000823                    Homo sapiens
# 1000945                    Homo sapiens
# ...                                 ...
# 1237356                    Homo sapiens
# 1237469                    Homo sapiens
# 1237481                    Homo sapiens
# 1237497                    Homo sapiens
# 1237593                    Homo sapiens
#
#          Sample Characteristic Ontology Term[organism]  \
# Id
# 1000221  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1000326  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1000662  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1000823  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1000945  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ...                                                ...
# 1237356  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1237469  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1237481  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1237497  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1237593  http://purl.obolibrary.org/obo/NCBITaxon_9606
#
#         Sample Characteristic[individual]  \
# Id
# 1000221                           1000221
# 1000326                           1000326
# 1000662                           1000662
# 1000823                           1000823
# 1000945                           1000945
# ...                                   ...
# 1237356                           1237356
# 1237469                           1237469
# 1237481                           1237481
# 1237497                           1237497
# 1237593                           1237593
#
#          Sample Characteristic Ontology Term[individual]  \
# Id
# 1000221                                              NaN
# 1000326                                              NaN
# 1000662                                              NaN
# 1000823                                              NaN
# 1000945                                              NaN
# ...                                                  ...
# 1237356                                              NaN
# 1237469                                              NaN
# 1237481                                              NaN
# 1237497                                              NaN
# 1237593                                              NaN
#
#         Sample Characteristic[sex]  \
# Id
# 1000221                     female
# 1000326                     female
# 1000662                     female
# 1000823                     female
# 1000945                     female
# ...                            ...
# 1237356                     female
# 1237469                     female
# 1237481                     female
# 1237497                     female
# 1237593                     female
#
#             Sample Characteristic Ontology Term[sex]  \
# Id
# 1000221  http://purl.obolibrary.org/obo/PATO_0000383
# 1000326  http://purl.obolibrary.org/obo/PATO_0000383
# 1000662  http://purl.obolibrary.org/obo/PATO_0000383
# 1000823  http://purl.obolibrary.org/obo/PATO_0000383
# 1000945  http://purl.obolibrary.org/obo/PATO_0000383
# ...                                              ...
# 1237356  http://purl.obolibrary.org/obo/PATO_0000383
# 1237469  http://purl.obolibrary.org/obo/PATO_0000383
# 1237481  http://purl.obolibrary.org/obo/PATO_0000383
# 1237497  http://purl.obolibrary.org/obo/PATO_0000383
# 1237593  http://purl.obolibrary.org/obo/PATO_0000383
#
#         Sample Characteristic[age]  Sample Characteristic Ontology Term[age]  \
# Id
# 1000221                    60 year                                       NaN
# 1000326                    60 year                                       NaN
# 1000662                    60 year                                       NaN
# 1000823                    60 year                                       NaN
# 1000945                    60 year                                       NaN
# ...                            ...                                       ...
# 1237356                    60 year                                       NaN
# 1237469                    60 year                                       NaN
# 1237481                    60 year                                       NaN
# 1237497                    60 year                                       NaN
# 1237593                    60 year                                       NaN
#
#         Sample Characteristic[developmental stage]  \
# Id
# 1000221                          human adult stage
# 1000326                          human adult stage
# 1000662                          human adult stage
# 1000823                          human adult stage
# 1000945                          human adult stage
# ...                                            ...
# 1237356                          human adult stage
# 1237469                          human adult stage
# 1237481                          human adult stage
# 1237497                          human adult stage
# 1237593                          human adult stage
#
#         Sample Characteristic Ontology Term[developmental stage]  ...  \
# Id                                                                ...
# 1000221      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1000326      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1000662      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1000823      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1000945      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# ...                                                    ...        ...
# 1237356      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1237469      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1237481      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1237497      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
# 1237593      http://purl.obolibrary.org/obo/HsapDv_0000087        ...
#
#         Factor Value[disease]          Factor Value Ontology Term[disease]  \
# Id
# 1000221                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1000326                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1000662                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1000823                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1000945                normal  http://purl.obolibrary.org/obo/PATO_0000461
# ...                       ...                                          ...
# 1237356                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1237469                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1237481                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1237497                normal  http://purl.obolibrary.org/obo/PATO_0000461
# 1237593                normal  http://purl.obolibrary.org/obo/PATO_0000461
#
#         Factor Value[sampling site] Factor Value Ontology Term[sampling site]  \
# Id
# 1000221                blood plasma                                       nan
# 1000326                blood plasma                                       nan
# 1000662                blood plasma                                       nan
# 1000823                blood plasma                                       nan
# 1000945                blood plasma                                       nan
# ...                             ...                                       ...
# 1237356                blood plasma                                       nan
# 1237469                blood plasma                                       nan
# 1237481                blood plasma                                       nan
# 1237497                blood plasma                                       nan
# 1237593                blood plasma                                       nan
#
#         Factor Value[inferred cell type - ontology labels]  \
# Id
# 1000221                                                nan
# 1000326                                                nan
# 1000662                                                nan
# 1000823                                                nan
# 1000945                                                nan
# ...                                                    ...
# 1237356                                                nan
# 1237469                                                nan
# 1237481                                                nan
# 1237497                                                nan
# 1237593                                                nan
#
#         Factor Value Ontology Term[inferred cell type - ontology labels]  \
# Id
# 1000221                                                nan
# 1000326                                                nan
# 1000662                                                nan
# 1000823                                                nan
# 1000945                                                nan
# ...                                                    ...
# 1237356                                                nan
# 1237469                                                nan
# 1237481                                                nan
# 1237497                                                nan
# 1237593                                                nan
#
#         Factor Value[inferred cell type - authors labels]  \
# Id
# 1000221                                               nan
# 1000326                                               nan
# 1000662                                               nan
# 1000823                                               nan
# 1000945                                               nan
# ...                                                   ...
# 1237356                                               nan
# 1237469                                               nan
# 1237481                                               nan
# 1237497                                               nan
# 1237593                                               nan
#
#         Factor Value Ontology Term[inferred cell type - authors labels]  \
# Id
# 1000221                                                nan
# 1000326                                                nan
# 1000662                                                nan
# 1000823                                                nan
# 1000945                                                nan
# ...                                                    ...
# 1237356                                                nan
# 1237469                                                nan
# 1237481                                                nan
# 1237497                                                nan
# 1237593                                                nan
#
#          str_batch  celltype
# Id
# 1000221          3       nan
# 1000326          3       nan
# 1000662          3       nan
# 1000823          3       nan
# 1000945          3       nan
# ...            ...       ...
# 1237356          3       nan
# 1237469          3       nan
# 1237481          3       nan
# 1237497          3       nan
# 1237593          3       nan
#
# [2000 rows x 32 columns]

# %%
Odata.var
# Out:
#          gene_name
# EIF4EBP1  EIF4EBP1
# EIF4G1      EIF4G1
# EIF5A        EIF5A
# ENAH          ENAH
# ENG            ENG
# ...            ...
# CHGB          CHGB
# CHGA          CHGA
# CHRM1        CHRM1
# KLK1          KLK1
# WFDC2        WFDC2
#
# [2917 rows x 1 columns]

# %% [markdown]
# ## Get sex data

# %%
OLINK_pheno=pd.read_csv('/shared/eduff/meg_ukb671140.csv')
OLINK_pheno=OLINK_pheno.set_index('eid')
OLINK_pheno.head()
# Out:
#          1558-0.0  1558-1.0  1558-2.0  1558-3.0  20116-0.0  20116-1.0  \
# eid
# 1000037       3.0       NaN       NaN       NaN        1.0        NaN
# 1000221       2.0       NaN       NaN       NaN        0.0        NaN
# 1000326       1.0       NaN       NaN       NaN        1.0        NaN
# 1000662       5.0       NaN       NaN       NaN        0.0        NaN
# 1000823       3.0       NaN       NaN       NaN        2.0        NaN
#
#          20116-2.0  20116-3.0  21000-0.0  21000-1.0  ...  20003-3.38  \
# eid                                                  ...
# 1000037        NaN        NaN     1001.0        NaN  ...         NaN
# 1000221        NaN        NaN     1001.0        NaN  ...         NaN
# 1000326        NaN        NaN     1001.0        NaN  ...         NaN
# 1000662        NaN        NaN     1001.0        NaN  ...         NaN
# 1000823        NaN        NaN     1001.0        NaN  ...         NaN
#
#          20003-3.39  20003-3.40  20003-3.41  20003-3.42  20003-3.43  \
# eid
# 1000037         NaN         NaN         NaN         NaN         NaN
# 1000221         NaN         NaN         NaN         NaN         NaN
# 1000326         NaN         NaN         NaN         NaN         NaN
# 1000662         NaN         NaN         NaN         NaN         NaN
# 1000823         NaN         NaN         NaN         NaN         NaN
#
#          20003-3.44  20003-3.45  20003-3.46  20003-3.47
# eid
# 1000037         NaN         NaN         NaN         NaN
# 1000221         NaN         NaN         NaN         NaN
# 1000326         NaN         NaN         NaN         NaN
# 1000662         NaN         NaN         NaN         NaN
# 1000823         NaN         NaN         NaN         NaN
#
# [5 rows x 282 columns]

# %%
def getSexFromBioBankData(adata):
    Odata = adata.copy()
    els=[int(i) for i in Odata.obs.index]
    gender_info = OLINK_pheno.loc[els, '31-0.0']
    gender_info = gender_info.map({1: 1, 0: 0})
    # print(gender_info)

    Odata.obs['sex'] = gender_info.values

    return Odata

# %%
Odata_train_with_sex = getSexFromBioBankData(Odata_train_matched)
Odata_test_with_sex = getSexFromBioBankData(Odata_test_matched)

# %%
Odata_train_with_sex.obs
# Out:
#          sex
# Id
# 5116579    0
# 1355096    0
# 1600706    1
# 5086035    1
# 2197383    0
# ...      ...
# 5933100    0
# 4672729    0
# 3245023    1
# 2601604    1
# 1009975    1
#
# [8704 rows x 1 columns]

# %% [markdown]
# ## Get age data

# %%
OLINK_pheno=pd.read_csv('/shared/eduff/meg_ukb671140.csv')
OLINK_pheno=OLINK_pheno.set_index('eid')
OLINK_pheno
# Out:
#          1558-0.0  1558-1.0  1558-2.0  1558-3.0  20116-0.0  20116-1.0  \
# eid
# 1000037       3.0       NaN       NaN       NaN        1.0        NaN
# 1000221       2.0       NaN       NaN       NaN        0.0        NaN
# 1000326       1.0       NaN       NaN       NaN        1.0        NaN
# 1000662       5.0       NaN       NaN       NaN        0.0        NaN
# 1000823       3.0       NaN       NaN       NaN        2.0        NaN
# ...           ...       ...       ...       ...        ...        ...
# 6023823       3.0       NaN       NaN       NaN        0.0        NaN
# 6023922       6.0       NaN       NaN       NaN        1.0        NaN
# 6024013       2.0       NaN       NaN       NaN        0.0        NaN
# 6024025       2.0       NaN       NaN       NaN        1.0        NaN
# 6024081       6.0       NaN       NaN       NaN        0.0        NaN
#
#          20116-2.0  20116-3.0  21000-0.0  21000-1.0  ...  20003-3.38  \
# eid                                                  ...
# 1000037        NaN        NaN     1001.0        NaN  ...         NaN
# 1000221        NaN        NaN     1001.0        NaN  ...         NaN
# 1000326        NaN        NaN     1001.0        NaN  ...         NaN
# 1000662        NaN        NaN     1001.0        NaN  ...         NaN
# 1000823        NaN        NaN     1001.0        NaN  ...         NaN
# ...            ...        ...        ...        ...  ...         ...
# 6023823        NaN        NaN     1001.0        NaN  ...         NaN
# 6023922        NaN        NaN     1001.0        NaN  ...         NaN
# 6024013        NaN        NaN     1001.0        NaN  ...         NaN
# 6024025        NaN        NaN     1001.0        NaN  ...         NaN
# 6024081        NaN        NaN     3002.0        NaN  ...         NaN
#
#          20003-3.39  20003-3.40  20003-3.41  20003-3.42  20003-3.43  \
# eid
# 1000037         NaN         NaN         NaN         NaN         NaN
# 1000221         NaN         NaN         NaN         NaN         NaN
# 1000326         NaN         NaN         NaN         NaN         NaN
# 1000662         NaN         NaN         NaN         NaN         NaN
# 1000823         NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 6023823         NaN         NaN         NaN         NaN         NaN
# 6023922         NaN         NaN         NaN         NaN         NaN
# 6024013         NaN         NaN         NaN         NaN         NaN
# 6024025         NaN         NaN         NaN         NaN         NaN
# 6024081         NaN         NaN         NaN         NaN         NaN
#
#          20003-3.44  20003-3.45  20003-3.46  20003-3.47
# eid
# 1000037         NaN         NaN         NaN         NaN
# 1000221         NaN         NaN         NaN         NaN
# 1000326         NaN         NaN         NaN         NaN
# 1000662         NaN         NaN         NaN         NaN
# 1000823         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...
# 6023823         NaN         NaN         NaN         NaN
# 6023922         NaN         NaN         NaN         NaN
# 6024013         NaN         NaN         NaN         NaN
# 6024025         NaN         NaN         NaN         NaN
# 6024081         NaN         NaN         NaN         NaN
#
# [53074 rows x 282 columns]

# %%
def setDoBDataFromBioBankData(adata):
    Odata = adata.copy()
    
    els=[int(a) for a in Odata.obs.index]
    
    DoB_Year = OLINK_pheno.loc[els, '34-0.0']
    DoB_Month = OLINK_pheno.loc[els, '52-0.0']
    
    Odata.obs['DoB_Year'] = DoB_Year.values
    Odata.obs['DoB_Month'] = DoB_Month.values
    # Odata.obs['DoB_Time'] = DoB_Year.values + DoB_Month.values/12.0
    Odata.obs = Odata.obs.assign(DoB_Day=15)

    Odata.obs['DoB_Year'] = Odata.obs['DoB_Year'].astype(int)
    Odata.obs['DoB_Month'] = Odata.obs['DoB_Month'].astype(int)
    Odata.obs['DoB_Day'] = Odata.obs['DoB_Day'].astype(int)

    Odata.obs['DoB'] = Odata.obs.apply(lambda row: pd.to_datetime(f"{row['DoB_Year']}-{row['DoB_Month']}-{row['DoB_Day']}"), axis=1)
    Odata.obs['DoB'] = pd.to_datetime(Odata.obs['DoB'])

    return Odata

# %%
Odata_train_with_DoBData = setDoBDataFromBioBankData(Odata_train_with_sex)
Odata_test_with_DoBData = setDoBDataFromBioBankData(Odata_test_with_sex)

# %%
Odata_train_with_DoBData.obs
# Out:
#          sex  DoB_Year  DoB_Month  DoB_Day        DoB
# Id
# 5116579    0      1948         10       15 1948-10-15
# 1355096    0      1944          8       15 1944-08-15
# 1600706    1      1941          2       15 1941-02-15
# 5086035    1      1955          6       15 1955-06-15
# 2197383    0      1951          4       15 1951-04-15
# ...      ...       ...        ...      ...        ...
# 5933100    0      1951          9       15 1951-09-15
# 4672729    0      1957          6       15 1957-06-15
# 3245023    1      1948          5       15 1948-05-15
# 2601604    1      1960          3       15 1960-03-15
# 1009975    1      1942         12       15 1942-12-15
#
# [8704 rows x 5 columns]

# %%
from datetime import date
d0 = date(2008,8,18)
d1 = date(2009, 9,26)
delta = d1 - d0
type(d0)
# Out:
# datetime.date

# %%
def setDateofAttendingAssessmentFromBioBankData(adata):
    Odata = adata.copy()
    
    els=[int(a) for a in Odata.obs.index]
    Date_Attend = OLINK_pheno.loc[els, '53-0.0']
    
    Odata.obs['Date_Attend'] = Date_Attend.values
    Odata.obs['Date_Attend'] = pd.to_datetime(Odata.obs['Date_Attend'])


    # Odata.obs['Attend_Year'] = Odata.obs['Date_Attend'].dt.year
    # Odata.obs['Attend_Month'] = Odata.obs['Date_Attend'].dt.month

    # Odata.obs['Attend_Time'] = Odata.obs['Attend_Year'].values + Odata.obs['Attend_Month'].values/12.0

    # Odata.obs['Date_Attend'] = Date_Attend.values
    
    return Odata

# %%
Odata_train_with_attendData = setDateofAttendingAssessmentFromBioBankData(Odata_train_with_DoBData)
Odata_test_with_attendData = setDateofAttendingAssessmentFromBioBankData(Odata_test_with_DoBData)

# %%
Odata_train_with_attendData.obs
# Out:
#          sex  DoB_Year  DoB_Month  DoB_Day        DoB Date_Attend
# Id
# 5116579    0      1948         10       15 1948-10-15  2008-11-06
# 1355096    0      1944          8       15 1944-08-15  2010-05-14
# 1600706    1      1941          2       15 1941-02-15  2007-11-05
# 5086035    1      1955          6       15 1955-06-15  2008-05-13
# 2197383    0      1951          4       15 1951-04-15  2009-11-17
# ...      ...       ...        ...      ...        ...         ...
# 5933100    0      1951          9       15 1951-09-15  2009-11-11
# 4672729    0      1957          6       15 1957-06-15  2009-03-10
# 3245023    1      1948          5       15 1948-05-15  2008-03-01
# 2601604    1      1960          3       15 1960-03-15  2008-08-06
# 1009975    1      1942         12       15 1942-12-15  2010-06-17
#
# [8704 rows x 6 columns]

# %%
Odata_train_with_attendData.obs.dtypes
# Out:
# sex                     int64
# DoB_Year                int64
# DoB_Month               int64
# DoB_Day                 int64
# DoB            datetime64[ns]
# Date_Attend    datetime64[ns]
# dtype: object

# %%
def setAge(adata):
    Odata = adata.copy()
    
    # Odata.obs['age'] = (Odata.obs['Attend_Time']- Odata.obs['DoB_Time'])
    # Odata.obs['age'] = Odata.obs['age'].round(2)

    Odata.obs['age'] = (Odata.obs['Date_Attend'] - Odata.obs['DoB']).dt.days / 365.25

    # set data type to avoid the save adata error
    Odata.obs['DoB'] = Odata.obs['DoB'].dt.strftime('%Y-%m-%d')
    Odata.obs['Date_Attend'] = Odata.obs['Date_Attend'].dt.strftime('%Y-%m-%d')
    
    return Odata

# %%
Odata_train_with_age = setAge(Odata_train_with_attendData)
Odata_test_with_age = setAge(Odata_test_with_attendData)

# %%
Odata_train_with_age.obs
# Out:
#          sex  DoB_Year  DoB_Month  DoB_Day         DoB Date_Attend        age
# Id
# 5116579    0      1948         10       15  1948-10-15  2008-11-06  60.060233
# 1355096    0      1944          8       15  1944-08-15  2010-05-14  65.744011
# 1600706    1      1941          2       15  1941-02-15  2007-11-05  66.718686
# 5086035    1      1955          6       15  1955-06-15  2008-05-13  52.911704
# 2197383    0      1951          4       15  1951-04-15  2009-11-17  58.592745
# ...      ...       ...        ...      ...         ...         ...        ...
# 5933100    0      1951          9       15  1951-09-15  2009-11-11  58.157426
# 4672729    0      1957          6       15  1957-06-15  2009-03-10  51.734428
# 3245023    1      1948          5       15  1948-05-15  2008-03-01  59.794661
# 2601604    1      1960          3       15  1960-03-15  2008-08-06  48.394251
# 1009975    1      1942         12       15  1942-12-15  2010-06-17  67.504449
#
# [8704 rows x 7 columns]

# %%
Odata_train_with_age.obs.dtypes
# Out:
# sex              int64
# DoB_Year         int64
# DoB_Month        int64
# DoB_Day          int64
# DoB             object
# Date_Attend     object
# age            float64
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.hist(Odata_train_with_age.obs['age'], bins=30, edgecolor='k')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Ages')
plt.show()

# %%
def ageCluster(adata):
    Odata = adata.copy()

    # 定义年龄分段
    bins = [40, 50, 60, 70, 80]
    labels = ['40-50', '50-60', '60-70','70-80']
    
    # 使用 cut 方法进行分类
    Odata.obs['Age_Group'] = pd.cut(Odata.obs['age'], bins=bins, labels=labels, right=False)

    print(Odata.obs)

    age_group_counts = Odata.obs['Age_Group'].value_counts().sort_index()
    print(age_group_counts)

    return Odata

# %%
Odata_train_with_age_cluster = ageCluster(Odata_train_with_age)
Odata_test_with_age_cluster = ageCluster(Odata_test_with_age)
# Out:
#          sex  DoB_Year  DoB_Month  DoB_Day         DoB Date_Attend        age  \
# Id
# 5116579    0      1948         10       15  1948-10-15  2008-11-06  60.060233
# 1355096    0      1944          8       15  1944-08-15  2010-05-14  65.744011
# 1600706    1      1941          2       15  1941-02-15  2007-11-05  66.718686
# 5086035    1      1955          6       15  1955-06-15  2008-05-13  52.911704
# 2197383    0      1951          4       15  1951-04-15  2009-11-17  58.592745
# ...      ...       ...        ...      ...         ...         ...        ...
# 5933100    0      1951          9       15  1951-09-15  2009-11-11  58.157426
# 4672729    0      1957          6       15  1957-06-15  2009-03-10  51.734428
# 3245023    1      1948          5       15  1948-05-15  2008-03-01  59.794661
# 2601604    1      1960          3       15  1960-03-15  2008-08-06  48.394251
# 1009975    1      1942         12       15  1942-12-15  2010-06-17  67.504449
#
#         Age_Group
# Id
# 5116579     60-70
# 1355096     60-70
# 1600706     60-70
# 5086035     50-60
# 2197383     50-60
# ...           ...
# 5933100     50-60
# 4672729     50-60
# 3245023     50-60
# 2601604     40-50
# 1009975     60-70
#
# [8704 rows x 8 columns]
# Age_Group
# 40-50    1980
# 50-60    2821
# 60-70    3849
# 70-80      54
# Name: count, dtype: int64
#          sex  DoB_Year  DoB_Month  DoB_Day         DoB Date_Attend        age  \
# Id
# 2766252    1      1966          5       15  1966-05-15  2008-10-11  42.409309
# 2254174    0      1943          1       15  1943-01-15  2008-11-07  65.812457
# 4029539    1      1955         10       15  1955-10-15  2007-11-06  52.060233
# 5423753    1      1952          5       15  1952-05-15  2009-08-17  57.256674
# 2119269    1      1946          1       15  1946-01-15  2009-03-04  63.132101
# ...      ...       ...        ...      ...         ...         ...        ...
# 4767253    0      1941          7       15  1941-07-15  2008-07-11  66.989733
# 1765194    0      1957          8       15  1957-08-15  2009-06-26  51.863107
# 4285261    1      1948          3       15  1948-03-15  2009-07-16  61.336071
# 5799851    0      1952          6       15  1952-06-15  2008-07-01  56.043806
# 5209981    0      1944          7       15  1944-07-15  2009-09-17  65.174538
#
#         Age_Group
# Id
# 2766252     40-50
# 2254174     60-70
# 4029539     50-60
# 5423753     50-60
# 2119269     60-70
# ...           ...
# 4767253     60-70
# 1765194     50-60
# 4285261     60-70
# 5799851     50-60
# 5209981     60-70
#
# [3731 rows x 8 columns]
# Age_Group
# 40-50     830
# 50-60    1198
# 60-70    1678
# 70-80      25
# Name: count, dtype: int64

# %% [markdown]
# ### Fake data

# %%
Odata.obs['sex'] = 0  # 初始化列
Odata.obs.iloc[:299, Odata.obs.columns.get_loc('sex')] = 1
Odata.obs.iloc[300:599, Odata.obs.columns.get_loc('sex')] = 2
Odata.obs.iloc[600:899, Odata.obs.columns.get_loc('sex')] = 3
Odata.obs.iloc[900:1000,Odata.obs.columns.get_loc('sex')] = 4

# %%
Odata.obs
# Out:
#          sex
# Id
# 1000221    1
# 1000326    1
# 1000662    1
# 1000823    1
# 1000945    1
# ...      ...
# 1124392    4
# 1124453    4
# 1124594    4
# 1124617    4
# 1124915    4
#
# [1000 rows x 1 columns]

# %%
Odata.obs.dtypes
# Out:
# sex    int64
# dtype: object

# %%
Odata.X
# Out:
# array([[0.75756712, 1.05973776, 0.81593332, ..., 1.15026781, 1.23428036,
#         1.03345226],
#        [1.06221344, 2.29367793, 1.00201061, ..., 0.98589464, 0.73487288,
#         1.03345226],
#        [1.04225113, 1.41731008, 0.94009768, ..., 0.96449787, 0.96967555,
#         1.18637255],
#        ...,
#        [0.62558883, 0.64716592, 1.13106043, ..., 0.97374337, 0.98147054,
#         0.87453021],
#        [1.26973817, 0.71192432, 0.98715767, ..., 1.04807525, 0.7798086 ,
#         0.8538017 ],
#        [1.35965287, 1.85586897, 0.97423427, ..., 1.08232248, 1.23428036,
#         1.03345226]])

# %% [markdown]
# ### Save data

# %%
Odata_train_with_age_cluster.write("../../data/3-OLINK_data_sub_train_new.h5ad")
Odata_test_with_age_cluster.write("../../data/3-OLINK_data_sub_test_new.h5ad")
