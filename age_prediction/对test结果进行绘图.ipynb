# %%
import scanpy as sc
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/data/mr423/project/code/save/biobank-Aug19-11-32/output.csv")

# %%
df
# Out:
#       Predictions  Target
# 0            65.8    60.5
# 1            64.8    58.9
# 2            62.1    62.1
# 3            66.6    66.7
# 4            53.4    44.2
# ...           ...     ...
# 4140         62.0    62.5
# 4141         62.2    63.9
# 4142         54.9    57.5
# 4143         61.0    65.6
# 4144         64.1    61.6
#
# [4145 rows x 2 columns]

# %%
bins = np.arange(30, 100, 10)

plt.figure(figsize=(6, 5)) 
counts, bins, patches = plt.hist(df['Target'], bins=bins, edgecolor='black') 
plt.xlabel('The histogram of Target')
plt.ylabel('Frequency')

for count, bin in zip(counts, bins):
    plt.text(bin + 5, count, str(int(count)), ha='center', va='bottom')


plt.show()

# %%
bins = np.arange(30, 100, 10)

plt.figure(figsize=(6, 5)) 
counts, bins, patches = plt.hist(df['Predictions'], bins=bins, edgecolor='black') 
plt.xlabel('The histogram of Predictions')
plt.ylabel('Frequency')

for count, bin in zip(counts, bins):
    plt.text(bin + 5, count, str(int(count)), ha='center', va='bottom')


plt.show()
