# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import scanpy as sc
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
adata = sc.read("../data/3-OLINK_data_sub_train.h5ad")
adata_test = sc.read("../data/3-OLINK_data_sub_test.h5ad")

# %%
adata.obs
# Out:
#          sex  DoB_Year  DoB_Month  DoB_Day         DoB Date_Attend        age  \
# Id
# 4345870    0      1954          5       15  1954-05-15  2006-05-09  51.983573
# 4470636    1      1962          4       15  1962-04-15  2008-01-25  45.779603
# 3236504    0      1946         10       15  1946-10-15  2008-05-31  61.626283
# 3306041    1      1943          5       15  1943-05-15  2010-04-01  66.880219
# 3306375    0      1944          3       15  1944-03-15  2007-11-15  63.668720
# ...      ...       ...        ...      ...         ...         ...        ...
# 5224082    0      1945          3       15  1945-03-15  2008-06-05  63.225188
# 1887434    0      1958          6       15  1958-06-15  2009-05-20  50.929500
# 3205452    1      1946          5       15  1946-05-15  2010-06-25  64.112252
# 5933100    0      1951          9       15  1951-09-15  2009-11-11  58.157426
# 4672729    0      1957          6       15  1957-06-15  2009-03-10  51.734428
#
#         Age_Group
# Id
# ...

# %%
data = pd.read_csv("../data/3-OLINK_data_sub_train_norm.csv")
data_test = pd.read_csv("../data//3-OLINK_data_sub_test_norm.csv")

# %%
data=data.set_index('Id')
data_test=data_test.set_index('Id')

# %%
data
# Out:
#          EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2     ENPP5  \
# Id
# 4345870  0.724747  0.193398  0.709988  0.491867  0.771465  0.712243  0.620365
# 4470636  0.202809  0.099662  0.809039  0.442721  0.807165  0.633537  0.621622
# 3236504  0.434471  0.538157  0.654836  0.519014  0.607882  0.474799  0.000000
# 3306041  0.432549  0.313378  0.664103  0.525573  0.766192  0.496753  0.571659
# 3306375  0.472101  0.768591  0.620799  0.549395  0.689148  0.403333  0.453147
# ...           ...       ...       ...       ...       ...       ...       ...
# 5224082  0.483224  0.524163  0.609242  0.503507  0.814350  0.775715  0.491652
# 1887434  0.376776  0.190302  0.424855  0.301992  0.759570  0.726096  0.476135
# 3205452  0.467452  0.431559  0.723379  0.600583  0.820330  0.587739  0.665996
# 5933100  0.514131  0.605425  0.554335  0.649379  0.799588  0.547266  0.656944
# 4672729  0.362084  0.163084  0.647865  0.451569  0.775020  0.761756  0.592500
#
# ...

# %%
data_test
# Out:
#          EIF4EBP1    EIF4G1     EIF5A      ENAH       ENG     ENPP2     ENPP5  \
# Id
# 4228635  0.604328  0.694501  0.519439  0.534292  0.663294  0.922466  0.492302
# 1763478  0.315606  0.161763  0.626951  0.525020  0.754487  0.565872  0.624633
# 1611073  0.301986  0.189747  0.703800  0.425139  0.785088  0.863230  0.471514
# 1057039  0.499012  0.410316  0.697308  0.677699  0.690342  0.606945  0.594402
# 2018635  0.634797  0.334489  0.749194  0.503788  0.804898  0.553724  0.666446
# ...           ...       ...       ...       ...       ...       ...       ...
# 1275089  0.457837  0.585462  0.785211  0.656410  0.789744  0.601417  0.319303
# 1436569  0.459881  0.488294  0.801966  0.596325  0.826522  0.698768  0.483142
# 4986938  0.636026  0.652038  0.620170  0.624984  0.861898  0.945913  0.488080
# 2405742  0.323032  0.089536  0.797719  0.465772  0.730320  0.511049  0.000000
# 2801719  0.660247  0.875800  0.715449  0.566243  0.792649  0.726580  0.488313
#
# ...

# %%
y_train = adata.obs['age']
y_test = adata_test.obs['age']

# %%
# scaler = StandardScaler()

# y_train_scaled = scaler.fit_transform(pred.values.reshape(-1, 1)).flatten()
# y_test_scaled = scaler.transform(y_test.values.reshape(-1, 1)).flatten()

# %%
# y_test_scaled

# %%
# 分割数据为训练集和测试集
# X_train, X_val, y_train, y_val = train_test_split(data, y_train_scaled, test_size=0.3, random_state=0)

# %%
# 初始化并训练线性回归模型
model = LinearRegression()
model.fit(data, y_train)
# Out:
# LinearRegression()

# %%
# 进行预测
y_train_pred = model.predict(data)

# 评估模型性能
train_mse = mean_squared_error(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)

# 打印评估结果
print("train:")
print(f"均方误差 (MSE): {train_mse:.4f}")
print(f"平均绝对误差 (MAE): {train_mae:.4f}")
print(f"决定系数 (R²): {train_r2:.4f}")
# Out:
# train:
# 均方误差 (MSE): 4.0560
# 平均绝对误差 (MAE): 1.6009
# 决定系数 (R²): 0.9400

# %%
# y_val_pred = model.predict(X_val)
# y_val_pred

# %%
# y_val_pred = scaler.inverse_transform(y_val_pred.reshape(-1, 1)).flatten()
# y_val = scaler.inverse_transform(y_val.reshape(-1, 1)).flatten()

# val_mse = mean_squared_error(y_val, y_val_pred)
# val_mae = mean_absolute_error(y_val, y_val_pred)
# val_r2 = r2_score(y_val, y_val_pred)

# print("val:")
# print(f"均方误差 (MSE): {val_mse:.4f}")
# print(f"平均绝对误差 (MAE): {val_mae:.4f}")
# print(f"决定系数 (R²): {val_r2:.4f}")

# %%
y_test_pred = model.predict(data_test)
# y_test_pred = scaler.inverse_transform(y_test_pred.reshape(-1, 1)).flatten()

y_test_pred
# Out:
# array([61.47412872, 58.50869357, 55.7312556 , ..., 64.22010232,
#        62.88808724, 46.84815118])

# %%
test_mse = mean_squared_error(y_test, y_test_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)

print("test:")
print(f"均方误差 (MSE): {test_mse:.4f}")
print(f"平均绝对误差 (MAE): {test_mae:.4f}")
print(f"决定系数 (R²): {test_r2:.4f}")
# Out:
# test:
# 均方误差 (MSE): 16.5623
# 平均绝对误差 (MAE): 3.1905
# 决定系数 (R²): 0.7527
